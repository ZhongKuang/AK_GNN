# %%
import networkx as nx

import matplotlib.pyplot as plt
# %matplotlib inline


plt.rcParams['font.sans-serif']=['SimHei'] # 显示中文
plt.rcParams['axes.unicode_minus'] = False # 显示负号

# %% [markdown]
# ## 1.经典图结构

# %% [markdown]
# ### 1.1 全连接无向图

# %%
G = nx.complete_graph(7)

nx.draw(G)

# %%
## 查看全图连接数
G.size()
# Out:
# 21

# %% [markdown]
# ### 1.2 全连接有向图

# %%
G = nx.complete_graph(7,nx.DiGraph())

nx.draw(G)

# %%
## 判断是否有向
G.is_directed()
# Out:
# True

# %% [markdown]
# ### 1.3 环状图

# %%
G = nx.cycle_graph(5)

nx.draw(G)

# %% [markdown]
# ### 1.4 梯状图

# %%
G = nx.ladder_graph(5)
nx.draw(G)

# %% [markdown]
# ### 1.5 线性串珠图

# %%
G = nx.path_graph(15)
nx.draw(G)

# %% [markdown]
# ### 1.6 星状图

# %%
G = nx.star_graph(7)
nx.draw(G)

# %% [markdown]
# ### 1.7 轮辐图

# %%
## 在星状图的基础上，边缘的节点再依次相连
G = nx.wheel_graph(8)
nx.draw(G)

# %% [markdown]
# ### 1.8 二项树

# %%
G = nx.binomial_tree(5)
nx.draw(G)

# %% [markdown]
# ## 2. 栅格图

# %% [markdown]
# ### 2.1 二维矩形网格图

# %%
G = nx.grid_2d_graph(3,5)
nx.draw(G)

# %% [markdown]
# ### 2.2 多维矩形网格图

# %%
G = nx.grid_graph(dim=(2,3,5))
nx.draw(G)

# %% [markdown]
# ### 2.3 二维三角形网格图

# %%
G = nx.triangular_lattice_graph(2,5) # 2行5列个三角形
nx.draw(G)

# %% [markdown]
# ### 2.4 二维六边形蜂窝图

# %%
G = nx.hexagonal_lattice_graph(2,3)
nx.draw(G)

# %% [markdown]
# ### 2.5 n维超立方体图

# %%
G = nx.hypercube_graph(4)
nx.draw(G)

# %% [markdown]
# ## 3.NetworkX内置图

# %% [markdown]
# ### 3.1 钻石图

# %%
G = nx.diamond_graph()
nx.draw(G)

# %% [markdown]
# ### 3.2 牛角图

# %%
G = nx.bull_graph()
nx.draw(G)

# %%
G = nx.frucht_graph()
nx.draw(G)

# %% [markdown]
# ### 3.3 房图

# %%
G = nx.house_graph()
nx.draw(G)

# %% [markdown]
# ### 3.4 房图打叉

# %%
G = nx.house_x_graph()
nx.draw(G)

# %%
G = nx.petersen_graph()
nx.draw(G)

# %% [markdown]
# ### 3.5 风筝图

# %%
G = nx.krackhardt_kite_graph()
nx.draw(G)

# %% [markdown]
# ### 3.6 随机图

# %%
G = nx.erdos_renyi_graph(10,0.5)
nx.draw(G)

# %% [markdown]
# ## 4.有向图

# %% [markdown]
# ### 4.1 无标度有向图

# %%
G = nx.krackhardt_kite_graph()
nx.draw(G)

# %% [markdown]
# ## 5.社交网络
# * 空手道俱乐部数据集
# * 雨果《悲惨世界》人物关系
# * Florentine families graph

# %%
### 空手道俱乐部数据集
# 会员分成了两大派系，可以堪称是鸢尾花数据集
G = nx.karate_club_graph()
nx.draw(G,with_labels=True)

# %%
## 查询五号和九号节点分别属于哪个派系
print(G.nodes[5]["club"])
print(G.nodes[9]["club"])
# Out:
# Mr. Hi
# Officer

# %%
### 雨果《悲惨世界》人物关系
G = nx.les_miserables_graph()
plt.figure(figsize = (12,10))
pos = nx.spring_layout(G,seed = 10) # 绘制图时可以先生成布局，例如spring_layout弹簧布局,设置随机种子就可以完全复现
nx.draw(G,pos,with_labels=True)

# %%
### Florentine families graph
G = nx.florentine_families_graph()
nx.draw(G,with_labels=True)

# %% [markdown]
# ## 6.社群聚类图

# %%
G = nx.caveman_graph(4,3)
nx.draw(G,with_labels=True)

# %%
## 7.树结构

# %%
G = nx.random_tree(n=10,seed=0)
print(nx.forest_str(G,sources=[0]))
# Out:
# ╙── 0
#     ├── 3
#     └── 4
#         ├── 6
#         │   ├── 1
#         │   ├── 2
#         │   └── 7
#         │       └── 8
#         │           └── 5
#         └── 9
